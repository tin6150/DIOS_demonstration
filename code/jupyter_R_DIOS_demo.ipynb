# %%
# leave blank for easier insertion :-D

# %%
system('id -a; hostname; pwd -P')
# output in console

# %%
.libPaths()
# Out:
# [1] "/usr/local/lib/R/site-library" "/usr/lib/R/site-library"
# [3] "/usr/lib/R/library"

# %%
# .libPaths( c( .libPaths(), '/home/tin/R/x86_64-pc-linux-gnu-library/3.4' ) )

# %%
# install.packages("raster", repos = "http://cran.us.r-project.org")
# raster not avail for R 3.4.4    Mint isn't very up to date with R:-\
library(raster)
# Out:
# Loading required package: sp

# %%
.libPaths()
# Out:
# [1] "/usr/local/lib/R/site-library" "/usr/lib/R/site-library"
# [3] "/usr/lib/R/library"

# %%
## code from DIOS_demonstration.R follows

# %%
library(ggplot2)  
library(raster)   
library(mvnfast)    ## Fast Multivariate Normal and Student's t Methods
library(gstat)      ## Spatial and Spatio-Temporal Geostatistical Modelling, Prediction and Simulation
library(cowplot)  
library(geoR)       ## https://cran.r-project.org/web/packages/geoR/geoR.pdf
library(foreach)    ## Provides Foreach Looping Construct
library(doParallel) ## foreach parallel adapter https://cran.r-project.org/web/packages/doParallel/doParallel.pdf
library(tidyverse)  ## Pandas
library(rPref)      ## Database Preferences and Skyline Computation https://cran.r-project.org/web/packages/rPref/rPref.pdf
library(RColorBrewer)
# Out:
# ********************************************************
#
# Note: As of version 1.0.0, cowplot does not change the
#
#   default ggplot2 theme anymore. To recover the previous
#
#   behavior, execute:
#   theme_set(theme_cowplot())
#
# ********************************************************
#
#
# Warning message:
# “no DISPLAY variable so Tk is not available”
# --------------------------------------------------------------
#  Analysis of Geostatistical Data
#  For an Introduction to geoR go to http://www.leg.ufpr.br/geoR
#  geoR version 1.8-1 (built on 2020-02-08) is now loaded
# --------------------------------------------------------------
#
#
# Loading required package: iterators
#
# Loading required package: parallel
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ tibble  3.0.1     ✔ dplyr   0.8.5
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
# ✔ purrr   0.3.4
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ purrr::accumulate() masks foreach::accumulate()
# ✖ tidyr::extract()    masks raster::extract()
# ✖ dplyr::filter()     masks stats::filter()
# ✖ dplyr::lag()        masks stats::lag()
# ✖ dplyr::select()     masks raster::select()
# ✖ purrr::when()       masks foreach::when()
#
#
# Attaching package: ‘rPref’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     between

# %%
source("DIOS_demonstration_functions.R")  
set.seed(123)

# %%
#==========================================================
#                Demonstration setting
#==========================================================
#================== Parameters ======================
# parameters for points
##n.total <- 100
##n.initial <- 30

# cant change these cuz a few loops coded for 1:70
n.total   <- 34  ##100 # didnt work for 40, 74
n.initial <- 10  ## 30 #  didnt work for 6, 8
# don't seems to be able to lower either n.total or n.initial, later code have hard dependencies on these values
n.candidate = n.total - n.initial ## the remaining 70 sites that could be added to the network.  Trying to remove hard coding of 1..70 in code below

# parameters for linear part
beta0 <- 3 - log(100000)
beta1 <- 1

# parameters for spatial correlation
Y.sigmas <- 1             # sigma_s
Y.range <- c(0.1, 0.3)   # rho
Y.sigmad <- 0.1          # sigma_d

# parameters for the risk factor X
sigma <- 0.2

NumThread = 31 # cant do 128, error about socket # timing on 32 core no Logical Processor cascadelake 5218@2.3GHz: 62 => 3h7m. 32 -> 3h11m.  31 => 3h22m. 4 => 6hr. 
# number of realizations of the disease model to generate
##n.real <- 1000
#~n.real <- 200  
n.real <- 3  
# 32 core cascade lake 5218 2.3 GHz // 58 threads, but load avg peaked at ~9, mostly ~4.  (was actually hard coded to use 4)
# 200/100/30 (n.real/n.total/n.initial) ~3 hours.  100/100/30 ~2hr 
#  60/100/30 took ~90min.  
#  20/100/30 ~63min.  
#  10/100/30 ~53min  . 
# 400/60/30 fails. 600/60/30 fails.  400/90/30 fails.

# %%
#=========== generate point locations ================
coord <- data.frame(x = runif(n.total), y = runif(n.total), sampled = 0) # generate n.total random points in the unit grid
sampled.id <- sample(1:n.total, n.initial)   # sample n.initial points from them as the intial design
coord$sampled[sampled.id] <- 1
coord.sampled   <- coord[coord$sampled == 1,]   # initial sites
coord.unsampled <- coord[coord$sampled == 0,] # alternative sites

# %%
tin_test <- 5 +
        3

# %%
tin_test
# Out:
# [1] 8

# %%
#=========== generate risk factor X in the unit grid ==================
X.coord <- expand.grid(x = seq(0, 1, 0.01), y = seq(0, 1, 0.01)) # gernerate grid

# location of the two point sources. They are set to be far apart from each other.
center1 <- data.frame(x = 0.82, y = 0.55)
center2 <- data.frame(x = 0.24, y = 0.24)

# generate risk factor level
X.coord$Xvalue <- dnorm(sqrt((X.coord$x - center1$x)^2 + (X.coord$y - center1$y)^2), mean = 0, sd = sigma) + 
                  dnorm(sqrt((X.coord$x - center2$x)^2 + (X.coord$y - center2$y)^2), mean = 0, sd = sigma)

# %%
# plot risk factor
ggplot() + 
geom_tile(data = X.coord, aes(x = x, y = y, fill = Xvalue)) + 
coord_equal() +
theme_bw() +
scale_fill_distiller(palette = "RdYlGn") +
geom_point(data = coord[coord$sampled == 0,], aes(x, y), col = "gray60") +
geom_point(data = coord[coord$sampled == 1,], aes(x, y), shape = 17, size = 2) +
scale_color_manual(values = c("grey","black")) +
labs(color = "", fill = "X") +
guides(color = FALSE) +
xlab("") +
ylab("") +
geom_point(data = center1, aes(x = x, y = y), col = "blue") +
geom_point(data = center2, aes(x = x, y = y), col = "blue") +
scale_x_continuous(limits = c(0,1), expand = c(0,0)) +
scale_y_continuous(limits = c(0,1), expand = c(0,0))
# Out:
# plot without title

# %%
#============= extract X for sampled and alternative sites ==========
X.raster.raster <- rasterFromXYZ(X.coord)
coord.sampled$Xvalue <- raster::extract(X.raster.raster$Xvalue, coord.sampled[,1:2])
coord.unsampled$Xvalue <- raster::extract(X.raster.raster$Xvalue, coord.unsampled[,1:2])

# %%
#========= generate log(Y) when rho = 0.1 or 0.3 ================
sampled.dist <- as.matrix(dist(coord.sampled[,c("x","y")]))

# %%
for(i in 1:length(Y.range))
{
  set.seed(123)
  current.cov.sampled <- s.cov(sampled.dist, Y.sigmas, Y.range[i], Y.sigmad)
  ##coord.sampled[paste("logYValue",Y.range[i], sep = "")] <- beta0 + beta1*coord.sampled$Xvalue + rmvn(n = 1, mu = rep(0, n.initial), sigma = current.cov.sampled, ncores = 7)[1,]
  coord.sampled[paste("logYValue",Y.range[i], sep = "")] <- beta0 + beta1*coord.sampled$Xvalue + rmvn(n = 1, mu = rep(0, n.initial), sigma = current.cov.sampled, ncores = NumThread )[1,]
}

# %%
#========================= Figure 2 ==============================
Figure2A <- ggplot() + 
  geom_tile(data = X.coord, aes(x = x, y = y, fill = Xvalue)) + 
  scale_fill_distiller(palette = "Blues", direction = 1) +   # background color
  geom_point(data = coord[coord$sampled == 0,], aes(x, y), col = "gray50", shape = 1) +  # alternative sites
  geom_point(data = coord.sampled, aes(x, y),shape = 2, size = 3) +   # initial design
  geom_point(data = center1, aes(x = x, y = y), shape = 3, size = 2, col = "white") +   # point source 1
  geom_point(data = center2, aes(x = x, y = y), shape = 3, size = 2, col = "white") +   # point source 2
  labs(fill = "Risk factor", x = "", y = "") + 
  ggtitle("(A) Risk factor X") +
  coord_equal() + 
  theme_bw() + 
  theme(legend.position = "bottom", legend.key.size = unit(0.4, "cm")) + 
  scale_x_continuous(limits = c(0,1), expand = c(0,0)) + 
  scale_y_continuous(limits = c(0,1), expand = c(0,0))

# %%
# # kriging interpolation
coord.sampled.sp <- coord.sampled
coordinates(coord.sampled.sp) = ~ x+y

# %%
coord.grid <- X.coord
gridded(coord.grid) = ~x+y

# %%
krige0.1 <- krige(logYValue0.1 ~ Xvalue, coord.sampled.sp, coord.grid, model = vgm(psill = Y.sigmas^2, model = "Exp", range = Y.range[1], nugget = Y.sigmad^2), nsim = 1, nmax = 60, beta = c(beta0, beta1))
krige0.3 <- krige(logYValue0.3 ~ Xvalue, coord.sampled.sp, coord.grid, model = vgm(psill = Y.sigmas^2, model = "Exp", range = Y.range[2], nugget = Y.sigmad^2), nsim = 1, nmax = 60, beta = c(beta0, beta1))
# Out:
# [using conditional Gaussian simulation]
# [using conditional Gaussian simulation]

# %%
X.coord$Y0.1 <- krige0.1$sim1
X.coord$Y0.3 <- krige0.3$sim1

# %%
Figure2B <- ggplot() + 
  geom_tile(data = X.coord, aes(x = x, y = y, fill = Y0.1)) +   # background color
  geom_point(data = coord[coord$sampled == 0,], aes(x, y), col = "gray50", shape = 1) +  # alternative sites
  geom_point(data = coord.sampled, aes(x, y, fill = logYValue0.1),size = 3, shape = 2) + # initial design
  geom_point(data = center1, aes(x = x, y = y), shape = 3, size = 2, col = "black") +  # point source 1
  geom_point(data = center2, aes(x = x, y = y), shape = 3, size = 2, col = "black")  +  # point source 2
  geom_contour(data = X.coord, aes(x, y, z = Xvalue), col = "gray") +  # X
  scale_fill_distiller(palette = "RdYlGn", limits = c(min(c(coord.sampled$YValue0.1, coord.sampled$YValue0.3, X.coord$Y0.1, X.coord$Y0.3))-0.1, max(c(coord.sampled$YValue0.1, coord.sampled$YValue0.3, X.coord$Y0.1, X.coord$Y0.3))+0.1)) +
  labs(x = "", y = "", fill = "Log prevalence rate", title = expression("(B) Log prevalence rate when "~rho~" = 0.1")) + 
  coord_equal() + 
  theme_bw() + 
  theme(legend.position = "bottom", legend.key.size = unit(0.4, "cm")) + 
  scale_x_continuous(limits = c(0,1), expand = c(0,0)) + 
  scale_y_continuous(limits = c(0,1), expand = c(0,0))

# %%
Figure2C <- ggplot() + 
  geom_tile(data = X.coord, aes(x = x, y = y, fill = Y0.3)) + 
  geom_point(data = coord[coord$sampled == 0,], aes(x, y), col = "gray50", shape = 1) + 
  geom_point(data = coord.sampled, aes(x, y),shape = 2, size = 3) + 
  geom_point(data = center1, aes(x = x, y = y), shape = 3, size = 2, col = "black") + 
  geom_point(data = center2, aes(x = x, y = y), shape = 3, size = 2, col = "black") + 
  geom_contour(data = X.coord, aes(x, y, z = Xvalue), col = "gray") + 
  scale_fill_distiller(palette = "RdYlGn", limits = c(min(c(coord.sampled$YValue0.1, coord.sampled$YValue0.3, X.coord$Y0.1, X.coord$Y0.3))-0.1, max(c(coord.sampled$YValue0.1, coord.sampled$YValue0.3, X.coord$Y0.1, X.coord$Y0.3))+0.1)) +
  labs(x = "", y = "", fill = "Log prevalence rate", title = expression("(C) Log prevalence rate when "~rho~" = 0.3")) + 
  coord_equal() + 
  theme_bw() + 
  theme(legend.position = "bottom", legend.key.size = unit(0.4, "cm")) + 
  scale_x_continuous(limits = c(0,1), expand = c(0,0)) + 
  scale_y_continuous(limits = c(0,1), expand = c(0,0))

# %%
plot_grid(Figure2A, Figure2B, Figure2C, nrow = 1)
dev.off()
# Out:
# null device
#           1
# plot without title

# %%
#==========================================================
#               Fitting disease model
#==========================================================
# estimate parameters when rho = 0.1
coord.sampled.geodata <- as.geodata(coord.sampled, coords.col = 1:2, data.col = 5, covar.col = 4, covar.names = "Xvalue")

# %%
initial.ml.1 <- likfit(coords = coord.sampled[, c("x","y")], 
                       data = coord.sampled$logYValue0.1, 
                       trend = trend.spatial(~Xvalue, coord.sampled.geodata), 
                       ini.cov.pars = c(1, 1), 
                       fix.nugget = FALSE,
                       nugget = 1, 
                       cov.model = "exponential", 
                       lik.method = "ML")
## likfit - Likelihood Based Parameter Estimation For Gaussian Random Fields
## https://www.rdocumentation.org/packages/geoR/versions/1.8-1/topics/likfit
# Out:
# kappa not used for the exponential correlation function
# ---------------------------------------------------------------
# likfit: likelihood maximisation using the function optim.
# likfit: Use control() to pass additional
#          arguments for the maximisation function.
#         For further details see documentation for optim.
# likfit: It is highly advisable to run this function several
#         times with different initial values for the parameters.
# likfit: WARNING: This step can be time demanding!
# ---------------------------------------------------------------
# likfit: end of numerical maximisation.

# %%
# estimate parameters when rho = 0.3
coord.sampled.geodata <- as.geodata(coord.sampled, coords.col = 1:2, data.col = 5, covar.col = 4, covar.names = "Xvalue")

# %%
initial.ml.3 <- likfit(coords = coord.sampled[, c("x","y")], 
                       data = coord.sampled$logYValue0.3,     ## here is 0.3 instead of 0.1
                       trend = trend.spatial(~Xvalue, coord.sampled.geodata), 
                       ini.cov.pars = c(1, 0.3),              ## 0.3 instead of 1
                       fix.nugget = FALSE, 
                       nugget = 0.1,                          ## 0.1 instead of 1
                       cov.model = "exponential", 
                       lik.method = "ML")
# Out:
# kappa not used for the exponential correlation function
# ---------------------------------------------------------------
# likfit: likelihood maximisation using the function optim.
# likfit: Use control() to pass additional
#          arguments for the maximisation function.
#         For further details see documentation for optim.
# likfit: It is highly advisable to run this function several
#         times with different initial values for the parameters.
# likfit: WARNING: This step can be time demanding!
# ---------------------------------------------------------------
# likfit: end of numerical maximisation.

# %%
#==========================================================
#    Generate n.real realizations of the disease data
#==========================================================
#============ A. generate n.real sets of the unmeasured 70 sites ==========
# rho = 0.1
coord.sampled.sp <- coord.sampled
coordinates(coord.sampled.sp) = ~ x+y

coord.unsampled.sp <- coord.unsampled
coordinates(coord.unsampled.sp) = ~ x+y

# %%
krige0.1.sim <- krige(logYValue0.1 ~ Xvalue, coord.sampled.sp, coord.unsampled.sp, 
                      model = vgm(psill = (initial.ml.1$sigmasq)^2, 
                                  model = "Exp", range = initial.ml.1$phi, 
                                  nugget = (initial.ml.1$tausq)^2), 
                      nsim = n.real,   ## have tried as few as 10
                      nmax = 60, 
                      beta = c(initial.ml.1$beta[1],initial.ml.1$beta[2]))
# Out:
# [using conditional Gaussian simulation]

# %%
# rho = 0.3
krige0.3.sim <- krige(logYValue0.3 ~ Xvalue, 
                      coord.sampled.sp, 
                      coord.unsampled.sp, 
                      model = vgm(psill = (initial.ml.3$sigmasq)^2, 
                                  model = "Exp", 
                                  range = initial.ml.3$phi, 
                                  nugget = (initial.ml.3$tausq)^2), 
                      nsim = n.real, 
                      nmax = 60, 
                      beta = c(initial.ml.3$beta[1],initial.ml.3$beta[2])
                     )
# Out:
# [using conditional Gaussian simulation]

# %%
#=========== B. generate n.real realizations at the grid for Figure 3=========
# this is not part of DIOS, just for better visualization
# Generate the 41*41 grid 
X.coord <- expand.grid(x = seq(0, 1, 0.025), y = seq(0, 1, 0.025))
X.coord$Xvalue <- dnorm(sqrt((X.coord$x - center1$x)^2 + (X.coord$y - center1$y)^2), mean = 0, sd = sigma) + dnorm(sqrt((X.coord$x - center2$x)^2 + (X.coord$y - center2$y)^2), mean = 0, sd = sigma)

# %%
X.coord.sp <- X.coord
coordinates(X.coord.sp) = ~ x + y

# %%
# rho = 0.1
krige0.1.sim.grid <- krige(logYValue0.1 ~ Xvalue, coord.sampled.sp, X.coord.sp, model = vgm(psill = (initial.ml.1$sigmasq)^2, model = "Exp", range = initial.ml.1$phi, nugget = (initial.ml.1$tausq)^2), nsim = n.real, nmax = 60, beta = c(initial.ml.1$beta[1],initial.ml.1$beta[2]))
# Out:
# [using conditional Gaussian simulation]

# %%
# extract values for the unobserved sites
krige0.1.grid.extract <- list()
for(i in 1:n.real)
{
  current.data <- data.frame(x = X.coord$x, y = X.coord$y, YValue = krige0.1.sim.grid[[i]])
  current.raster <- rasterFromXYZ(current.data)
  krige0.1.grid.extract[[i]] <- raster::extract(current.raster$YValue, coord.unsampled[,1:2])
}

# %%
# rho = 0.3
krige0.3.sim.grid <- krige(logYValue0.3 ~ Xvalue, coord.sampled.sp, X.coord.sp, model = vgm(psill = (initial.ml.3$sigmasq)^2, model = "Exp", range = initial.ml.3$phi, nugget = (initial.ml.3$tausq)^2), nsim = n.real, nmax = 60, beta = c(initial.ml.3$beta[1],initial.ml.3$beta[2]))
# Out:
# [using conditional Gaussian simulation]

# %%
# extract values for the unobserved sites
krige0.3.grid.extract <- list()
for(i in 1:n.real)
{
  current.data <- data.frame(x = X.coord$x, y = X.coord$y, YValue = krige0.3.sim.grid[[i]])
  current.raster <- rasterFromXYZ(current.data)
  krige0.3.grid.extract[[i]] <- raster::extract(current.raster$YValue, coord.unsampled[,1:2])
}

# %%
#==========================================================
#           choose one optimal set
#==========================================================
# Since the design space is small, exhaustive search is done here

# %%
## okay next one finish <1 min when n.total, n.initial, n.candidate are reduced from 100/30/70 to 34/10/24

# %%
#=============== A. Evaluate objective function at alternative sites ========
#======== rho = 0.1 =========
# Took ~15 mins using 7 threads of Intel Core i7-7700 CPU        
cl <- makeCluster(detectCores()-1, outfile = "log_A_rho0.1.txt") ##
cl <- makeCluster(NumThread, outfile = "log.txt") ##
registerDoParallel(cl)

# %%
## next one takes ~3 minutes to complete

# %%
# loop over all realizations
OFV0.1 <- foreach(i = 1:n.real, .combine = "rbind", .packages = c("sp","gstat","geoR")) %dopar%
{
  cat(i, format(Sys.time(),usetz = TRUE), "\n")
  
  # loop over all 70 possible designs
  ## result <- data.frame(dataID = i, siteID = 1:70, OFV1 = NA, OFV2 = NA)
  result <- data.frame(dataID = i, siteID = 1:n.candidate, OFV1 = NA, OFV2 = NA)
  for(j in 1:n.candidate)   ## for(j in 1:70)
  {
    # combine intial design and the "selected" site
    coord.sampled.current.sp <- rbind(coord.sampled[,c("x","y","Xvalue","logYValue0.1")], 
                                      data.frame(x = coord.unsampled[j,"x"], 
                                                 y = coord.unsampled[j,"y"], 
                                                 Xvalue = coord.unsampled[j,"Xvalue"], 
                                                 logYValue0.1 = krige0.1.sim[[i]][j]))
    coord.sampled.geodata <- as.geodata(coord.sampled.current.sp, 
                                        coords.col = 1:2, 
                                        data.col = 4, 
                                        covar.col = 3, 
                                        covar.names = "Xvalue")
    coordinates(coord.sampled.current.sp) <- ~x+y
    
    # remove the "selected" site from the alternative site
    coord.unsampled.current.sp <- coord.unsampled[-j,]
    coordinates(coord.unsampled.current.sp) = ~x+y
    
    # predict the 69 unobserved sites
    krige.current.sim <- krige(logYValue0.1 ~ Xvalue, 
                               coord.sampled.current.sp, 
                               coord.unsampled.current.sp, 
                               model = vgm(psill = (initial.ml.1$sigmasq)^2, 
                                           model = "Exp", 
                                           range = initial.ml.1$phi, 
                                           nugget = (initial.ml.1$tausq)^2), 
                               beta = c(initial.ml.1$beta[1],initial.ml.1$beta[2]), 
                               debug.level = 0)
    
    # calculate MSE of the spatial prediction - objective 1
    result$OFV1[j] <- mean((krige.current.sim$var1.pred - krige0.1.sim[[i]][-j])^2)
    
    # calculate var(beta1) - Objective function 2
    current.ml <- likfit(coords = coordinates(coord.sampled.current.sp), 
                         data = coord.sampled.current.sp$logYValue0.1, 
                         trend = trend.spatial(~Xvalue, coord.sampled.geodata), 
                         ini.cov.pars = c(1, 0.3), 
                         fix.nugget = FALSE, 
                         nugget = 0.1, 
                         cov.model = "exponential", 
                         lik.method = "ML", 
                         messages = FALSE)
    
    result$OFV2[j] <- current.ml$beta.var[2,2]
  }
  result
}

# %%
## above takes a few minutes to complete
## don't stop cluster till above fisnish

# %%
stopCluster(cl)

# %%
#======== rho = 0.3 =============
# Took ~15 mins using 7 threads of Intel Core i7-7700 CPU
#cl <- makeCluster(detectCores()-1, outfile = "log.txt")
cl <- makeCluster(NumThread, outfile = "log_A_rho0.3.txt") ##
registerDoParallel(cl)
OFV0.3 <- foreach(i = 1:n.real, .combine = "rbind", .packages = c("sp","gstat","geoR")) %dopar%
{
  cat(i, format(Sys.time(),usetz = TRUE), "\n")
  
  ##result <- data.frame(dataID = i, siteID = 1:70, OFV1 = NA, OFV2 = NA)
  ##for(j in 1:70)

    
  result <- data.frame(dataID = i, siteID = 1:n.candidate, OFV1 = NA, OFV2 = NA)
  for(j in 1:n.candidate)
  {
    # MSE
    coord.sampled.current.sp <- rbind(coord.sampled[,c("x","y","Xvalue","logYValue0.3")], data.frame(x = coord.unsampled[j,"x"], y = coord.unsampled[j,"y"], Xvalue = coord.unsampled[j,"Xvalue"], logYValue0.3 = krige0.3.sim[[i]][j]))
    coord.sampled.geodata <- as.geodata(coord.sampled.current.sp, coords.col = 1:2, data.col = 4, covar.col = 3, covar.names = "Xvalue")
    coordinates(coord.sampled.current.sp) <- ~x+y
    
    coord.unsampled.current.sp <- coord.unsampled[-j,]
    coordinates(coord.unsampled.current.sp) = ~x+y
    
    krige.current.sim <- krige(logYValue0.3 ~ Xvalue, coord.sampled.current.sp, coord.unsampled.current.sp, model = vgm(psill = (initial.ml.3$sigmasq)^2, model = "Exp", range = initial.ml.3$phi, nugget = (initial.ml.3$tausq)^2), beta = c(initial.ml.3$beta[1],initial.ml.3$beta[2]), debug.level = 0)
    
    result$OFV1[j] <- mean((krige.current.sim$var1.pred - krige0.3.sim[[i]][-j])^2)
    # result$OFV1[j] <- mean((krige.current.sim$sim1 - krige0.3.mean[-j])^2)
    
    # var beta1
    current.ml <- likfit(coords = coordinates(coord.sampled.current.sp), data = coord.sampled.current.sp$logYValue0.3, trend = trend.spatial(~Xvalue, coord.sampled.geodata), ini.cov.pars = c(1, 0.3), fix.nugget = FALSE, nugget = 0.1, cov.model = "exponential", lik.method = "ML", messages = FALSE)
    
    result$OFV2[j] <- current.ml$beta.var[2,2]
  }
  
  result
}

# %%
##result
## pause...

# %%
stopCluster(cl)

# %%
##
## *** next one takes a long time !!! ***
##
## line 334 of DIOS_demonstration.R 
## this one still take ~2-3min with  n.total, n.initial, n.candidate to 34/10/24 
## (docker on bofh) start 11:53... load 3.1... end 11:57

# %%
#========= B. evaluate objective function at 41*41 grids as in Figure 3 ========
#======== rho = 0.1 =============
# Took ~9.5 hrs mins using 7 threads of Intel Core i7-7700 CPU
#cl <- makeCluster(detectCores()-1, outfile = "log.txt")
cl <- makeCluster(NumThread, outfile = "log_B_rho0.1.txt") ##
registerDoParallel(cl)
OFV0.1.grid <- foreach(i = 1:n.real, .combine = "rbind", .packages = c("sp","gstat","geoR")) %dopar%   # loop over all realizations
{
  cat(i, format(Sys.time(),usetz = TRUE), "\n")
  
  result <- data.frame(dataID = i, siteID = 1:nrow(X.coord), OFV1 = NA, OFV2 = NA)
  for(j in 1:nrow(X.coord))   # loop over all pixels
  {
    # MSE
    coord.sampled.current.sp <- rbind(coord.sampled[,c("x","y","Xvalue","logYValue0.1")], data.frame(x = X.coord[j,"x"], y = X.coord[j,"y"], Xvalue = X.coord[j,"Xvalue"], logYValue0.1 = krige0.1.sim.grid[[i]][j]))
    coord.sampled.geodata <- as.geodata(coord.sampled.current.sp, coords.col = 1:2, data.col = 4, covar.col = 3, covar.names = "Xvalue")
    coordinates(coord.sampled.current.sp) <- ~x+y
    
    coord.unsampled.current.sp <- coord.unsampled
    coordinates(coord.unsampled.current.sp) = ~x+y
    
    krige.current.sim <- krige(logYValue0.1 ~ Xvalue, coord.sampled.current.sp, coord.unsampled.current.sp, model = vgm(psill = (initial.ml.1$sigmasq)^2 , model = "Exp", range = initial.ml.1$phi, nugget = (initial.ml.1$tausq)^2), beta = c(initial.ml.1$beta[1],initial.ml.1$beta[2]), debug.level = 0)
    
    result$OFV1[j] <- mean((krige.current.sim$var1.pred - krige0.1.grid.extract[[i]])^2)
    
    # var beta1
    current.ml <- likfit(coords = coordinates(coord.sampled.current.sp), data = coord.sampled.current.sp$logYValue0.1, trend = trend.spatial(~Xvalue, coord.sampled.geodata), ini.cov.pars = c(1, 0.3), fix.nugget = FALSE, nugget = 0.1, cov.model = "exponential", lik.method = "ML", messages = FALSE)
    
    result$OFV2[j] <- current.ml$beta.var[2,2]
  }
  
  result
}
stopCluster(cl)

# %%
## line 370 of DIOS_demonstration.R 
## log portion takes ~1min?        (sites as 34/10/24)
## the whole thing takes ~8 min?

# %%
#======== rho = 0.3 =============
# Took ~9.5 hrs using 7 threads of Intel Core i7-7700 CPU
##cl <- makeCluster(detectCores()-1, outfile = "log.txt")
cl <- makeCluster(NumThread, outfile = "log_B_rho0.3.txt") ##
registerDoParallel(cl)
OFV0.3.grid <- foreach(i = 1:n.real, .combine = "rbind", .packages = c("sp","gstat","geoR")) %dopar%   # loop over all realizations
{
  cat(i, format(Sys.time(),usetz = TRUE), "\n")
  
  result <- data.frame(dataID = i, siteID = 1:nrow(X.coord), OFV1 = NA, OFV2 = NA)
  for(j in 1:nrow(X.coord))   # loop over all pixels
  {
    # MSE
    coord.sampled.current.sp <- rbind(coord.sampled[,c("x","y","Xvalue","logYValue0.3")], data.frame(x = X.coord[j,"x"], y = X.coord[j,"y"], Xvalue = X.coord[j,"Xvalue"], logYValue0.3 = krige0.3.sim.grid[[i]][j]))
    coord.sampled.geodata <- as.geodata(coord.sampled.current.sp, coords.col = 1:2, data.col = 4, covar.col = 3, covar.names = "Xvalue")
    coordinates(coord.sampled.current.sp) <- ~x+y
    
    coord.unsampled.current.sp <- coord.unsampled
    coordinates(coord.unsampled.current.sp) = ~x+y
    
    krige.current.sim <- krige(logYValue0.3 ~ Xvalue, coord.sampled.current.sp, coord.unsampled.current.sp, model = vgm(psill = (initial.ml.3$sigmasq)^2, model = "Exp", range = initial.ml.3$phi, nugget = (initial.ml.3$tausq)^2), beta = c(initial.ml.3$beta[1],initial.ml.3$beta[2]), debug.level = 0)
    
    result$OFV1[j] <- mean((krige.current.sim$var1.pred - krige0.3.grid.extract[[i]])^2)
    
    # var beta1
    current.ml <- likfit(coords = coordinates(coord.sampled.current.sp), data = coord.sampled.current.sp$logYValue0.3, trend = trend.spatial(~Xvalue, coord.sampled.geodata), ini.cov.pars = c(1, 0.3), fix.nugget = FALSE, nugget = 0.1, cov.model = "exponential", lik.method = "ML", messages = FALSE)
    
    result$OFV2[j] <- current.ml$beta.var[2,2]
  }
  
  result
}
stopCluster(cl)

# %%
#=========== plot results for selecting one additional site for each objective ====
#===========Figure 3 ===========
# coord.sampled <- read.csv("coord.sampled.csv")
# coord.unsampled <- read.csv("coord.unsampled.csv")
# 
# OFV0.1.grid <- read.csv("OFV 0.1 grid.csv")
# OFV0.3.grid <- read.csv("OFV 0.3 grid.csv")

OFV01.agg <- OFV0.1.grid %>% group_by(siteID) %>% summarise(OFV1 = mean(OFV1), OFV2 = mean(OFV2))
OFV03.agg <- OFV0.3.grid %>% group_by(siteID) %>% summarise(OFV1 = mean(OFV1), OFV2 = mean(OFV2))

OFV01.agg$x <- X.coord$x
OFV01.agg$y <- X.coord$y

OFV03.agg$x <- X.coord$x
OFV03.agg$y <- X.coord$y

OFV1.01.raster <- rasterFromXYZ(OFV01.agg[,c("x","y","OFV1","OFV2")])
coord.unsampled$OFV1.01 <- raster::extract(OFV1.01.raster$OFV1, coord.unsampled[,c("x","y")])
coord.unsampled$OFV2.01 <- raster::extract(OFV1.01.raster$OFV2, coord.unsampled[,c("x","y")])

OFV3.01.raster <- rasterFromXYZ(OFV03.agg[,c("x","y","OFV1","OFV2")])
coord.unsampled$OFV1.03 <- raster::extract(OFV3.01.raster$OFV1, coord.unsampled[,c("x","y")])
coord.unsampled$OFV2.03 <- raster::extract(OFV3.01.raster$OFV2, coord.unsampled[,c("x","y")])

# %%
Figure3A <- ggplot() + 
  geom_tile(data = OFV01.agg, aes(x = x, y = y, fill =  OFV1)) +  # OFV
  geom_point(data = center1, aes(x = x, y = y), shape = 3, size = 2, col = "white", stroke = 2) + # point source 1
  geom_point(data = center2, aes(x = x, y = y), shape = 3, size = 2, col = "white", stroke = 2) + # point source 2
  geom_point(data = coord.sampled, aes(x, y), shape = 2, size = 2) +  # initial design
  geom_point(data = coord.unsampled[-which.min(coord.unsampled$OFV1.01),], aes(x, y), col = "gray40", shape = 1, size = 2) +  # unselected alternative sites
  geom_point(data = coord.unsampled[which.min(coord.unsampled$OFV1.01),], aes(x = x, y = y), col = "cyan", shape = 1, stroke = 2, size = 2) +   # optimal site to add
  scale_fill_distiller(palette = "OrRd", direction = -1) + 
  scale_color_manual(values = c("grey","black")) + 
  scale_x_continuous(limits = c(0,1), expand = c(0,0)) + 
  scale_y_continuous(limits = c(0,1), expand = c(0,0))+
  labs(fill = "OFV 1", x = "", y = "") + 
  ggtitle("(A) Spatial interpolation, ρ = 0.1") +
  coord_equal() + 
  theme_bw()+ 
  theme(legend.position="bottom", legend.key.width = unit(1.2,"cm"), legend.key.height = unit(0.4,"cm"),legend.margin=margin(-20,0,0,0)) + 
  guides(color = FALSE, fill = guide_colourbar(label.theme = element_text(angle = 30, hjust = 1, size = 8), reverse = FALSE))

# %%
Figure3B <- ggplot() + 
  geom_tile(data = OFV03.agg, aes(x = x, y = y, fill =  OFV1)) + 
  geom_point(data = center1, aes(x = x, y = y), shape = 3, size = 2, col = "white", stroke = 2) + 
  geom_point(data = center2, aes(x = x, y = y), shape = 3, size = 2, col = "white", stroke = 2) + 
  geom_point(data = coord.sampled, aes(x, y), shape = 2, size = 2) + 
  geom_point(data = coord.unsampled[-which.min(coord.unsampled$OFV1.03),], aes(x, y), col = "gray40", shape = 1, size = 2) + 
  geom_point(data = coord.unsampled[which.min(coord.unsampled$OFV1.03),], aes(x = x, y = y), size = 2, col = "cyan", shape = 1, stroke = 2) + 
  scale_fill_distiller(palette = "OrRd", direction = -1) +
  scale_color_manual(values = c("grey","black")) + 
  scale_x_continuous(limits = c(0,1), expand = c(0,0)) + 
  scale_y_continuous(limits = c(0,1), expand = c(0,0))+ 
  labs(fill = "OFV 1", x = "", y = "") + 
  ggtitle("(B) Spatial interpolation, ρ = 0.3") + 
  coord_equal() + 
  theme_bw()+ 
  theme(legend.position="bottom", legend.key.width = unit(1.2,"cm"), legend.key.height = unit(0.4,"cm"),legend.margin=margin(-20,0,0,0)) + 
  guides(color = FALSE, fill = guide_colourbar(label.theme = element_text(angle = 30, hjust = 1, size = 8), reverse = FALSE))

# %%
Figure3C <- ggplot() + 
  geom_tile(data = OFV01.agg, aes(x = x, y = y, fill =  OFV2)) + 
  geom_point(data = center1, aes(x = x, y = y), shape = 3, size = 2, col = "white", stroke = 2) + 
  geom_point(data = center2, aes(x = x, y = y), shape = 3, size = 2, col = "white", stroke = 2) + 
  geom_point(data = coord.sampled, aes(x, y), shape = 2, size = 2) + 
  geom_point(data = coord.unsampled[-which.min(coord.unsampled$OFV2.01),], aes(x, y), size = 2, col = "gray40", shape = 1) + 
  geom_point(data = coord.unsampled[which.min(coord.unsampled$OFV2.01),], aes(x = x, y = y), size = 2, col = "cyan", shape = 1, stroke = 2) + 
  scale_fill_distiller(palette = "OrRd", direction = -1) + 
  scale_color_manual(values = c("grey","black")) + 
  scale_x_continuous(limits = c(0,1), expand = c(0,0)) + 
  scale_y_continuous(limits = c(0,1), expand = c(0,0))+ 
  labs(fill = "OFV 2", x = "", y = "") + 
  ggtitle("(C) Effect estimation, ρ = 0.1") + 
  coord_equal() + 
  theme_bw()+ 
  theme(legend.position="bottom", legend.key.width = unit(1.2,"cm"), legend.key.height = unit(0.4,"cm"), legend.margin=margin(-20,0,0,0)) + 
  guides(color = FALSE, size = guide_legend(nrow = 2, byrow = TRUE), fill = guide_colourbar(label.theme = element_text(angle = 30, hjust = 1, size = 8), reverse = FALSE))

# %%
Figure3D <- ggplot() + 
  geom_tile(data = OFV03.agg, aes(x = x, y = y, fill =  OFV2)) + 
  geom_point(data = center1, aes(x = x, y = y), shape = 3, size = 2, col = "white", stroke = 2) + 
  geom_point(data = center2, aes(x = x, y = y), shape = 3, size = 2, col = "white", stroke = 2) + 
  geom_point(data = coord.sampled, aes(x, y), shape = 2, size = 2) + 
  geom_point(data = coord.unsampled[-which.min(coord.unsampled$OFV2.03),], aes(x, y), size = 2, col = "gray40", shape = 1) + 
  geom_point(data = coord.unsampled[which.min(coord.unsampled$OFV2.03),], aes(x = x, y = y), size = 2, col = "cyan", shape = 1, stroke = 2) + 
  scale_fill_distiller(palette = "OrRd", direction = -1) + 
  scale_color_manual(values = c("grey","black")) + 
  scale_x_continuous(limits = c(0,1), expand = c(0,0)) + 
  scale_y_continuous(limits = c(0,1), expand = c(0,0))+ 
  labs(fill = "OFV 2", x = "", y = "") + 
  ggtitle("(D) Effect estimation, ρ = 0.3") +
  coord_equal() + 
  theme_bw()+ 
  theme(legend.position="bottom", legend.key.width = unit(1.2,"cm"), legend.key.height = unit(0.4,"cm"), legend.margin=margin(-20,0,0,0)) + 
  guides(size = guide_legend(nrow = 2, byrow = TRUE), fill = guide_colourbar(label.theme = element_text(angle = 30, hjust = 1, size = 8), reverse = FALSE))

# %%
plot_grid(Figure3A, Figure3B, Figure3C, Figure3D)
# Out:
# plot without title

# %%
#====== plot results for selecting one additional site for multiple objectives ====
#======= Figure 4 =======
# OFV0.3 <- read.csv("OFV 0.3.csv")
site.agg <- OFV0.3 %>% group_by(siteID) %>% summarize(OFV1 = mean(OFV1), OFV2 = mean(OFV2))

# OFV0.1 <- read.csv("OFV 0.1.csv")
# site.agg <- OFV0.1 %>% group_by(siteID) %>% summarize(OFV1 = mean(OFV1), OFV2 = mean(OFV2))

# %%
site.agg$x <- coord.unsampled$x
site.agg$y <- coord.unsampled$y

sky1 <- psel(site.agg, low(site.agg$OFV1)*low(site.agg$OFV2))
point.col <- brewer.pal(n = nrow(sky1), name = "Set1")

# %%
m.obj.p1 <- ggplot(site.agg, aes(x = OFV1, y = OFV2)) + 
  geom_point(shape = 21) + 
  geom_point(data = sky1, size = 3, aes(col = as.factor(siteID))) + 
  theme_bw() + 
  xlab("OFV 1 (spatial interpolation)") + 
  ylab("OFV 2 (effect estimation)") + 
  ggtitle("(A) Pareto set") + 
  scale_color_manual(values = point.col) + 
  guides(col = FALSE)

X.coord <- expand.grid(x = seq(0, 1, 0.01), y = seq(0, 1, 0.01)) # gernerate grid

# %%
# generate risk factor level
X.coord$Xvalue <- dnorm(sqrt((X.coord$x - center1$x)^2 + (X.coord$y - center1$y)^2), mean = 0, sd = sigma) + dnorm(sqrt((X.coord$x - center2$x)^2 + (X.coord$y - center2$y)^2), mean = 0, sd = sigma)

coord.grid <- X.coord
gridded(coord.grid) = ~x+y

# %%
krige0.1 <- krige(logYValue0.1 ~ Xvalue, coord.sampled.sp, coord.grid, model = vgm(psill = Y.sigmas^2, model = "Exp", range = Y.range[1], nugget = Y.sigmad^2), nsim = 1, nmax = 60, beta = c(beta0, beta1))
krige0.3 <- krige(logYValue0.3 ~ Xvalue, coord.sampled.sp, coord.grid, model = vgm(psill = Y.sigmas^2, model = "Exp", range = Y.range[2], nugget = Y.sigmad^2), nsim = 1, nmax = 60, beta = c(beta0, beta1))

X.coord$Y0.1 <- krige0.1$sim1
X.coord$Y0.3 <- krige0.3$sim1
# Out:
# [using conditional Gaussian simulation]
# [using conditional Gaussian simulation]

# %%
m.obj.p2 <- ggplot() + 
  geom_tile(data = X.coord, aes(x = x, y = y, fill = Y0.3)) + 
  scale_fill_distiller(palette = "RdYlGn", limits = c(min(c(coord.sampled$YValue0.1, coord.sampled$YValue0.3, X.coord$Y0.1, X.coord$Y0.3))-0.1, max(c(coord.sampled$YValue0.1, coord.sampled$YValue0.3, X.coord$Y0.1, X.coord$Y0.3))+0.1)) + 
  coord_equal() + 
  theme_bw() + 
  geom_contour(data = X.coord, aes(x, y, z = Xvalue), col = "gray") + 
  geom_point(data = site.agg, aes(x, y), col = "gray60") + 
  geom_point(data = coord.sampled, aes(x, y), shape = 17, size = 2) + 
  labs(color = "", fill = "log(prev)") + guides(color = FALSE, fill = FALSE) + 
  xlab("") + 
  ylab("") + 
  geom_point(data = sky1, aes(x = x, y = y, col = as.factor(siteID)), size = 4, shape = 17) + 
  scale_x_continuous(limits = c(0,1), expand = c(0,0)) + 
  scale_y_continuous(limits = c(0,1), expand = c(0,0)) + 
  ggtitle("(B) Locations of the Pareto set") + scale_color_manual(values = point.col) + 
  guides(col = FALSE)

# %%
plot_grid(m.obj.p1, m.obj.p2)
# Out:
# plot without title

# %%
## next step takes a while still !!
## but cpu isn't all that busy...
## docker on bofh: start 12:04... end ~12:19.  so ~15 min.  load avg <1.  
## so not sure why takes so long!  capturing that long ass output to the notebook?

# %%
#==========================================================
#       Optimization with simulated annealing
#==========================================================
# ================ SA ===============
# estimate initial temperature according to https://www.barnesandnoble.com/p/iterative-computer-algorithms-with-applications-in-engineering-sadiq-m-sait/1101198004/2660895534523?st=PLA&sid=BNB_ADL+Marketplace+Good+Used+Textbooks+-+Desktop+Low&sourceId=PLAGoNA&dpid=tdtve346c&2sid=Google_c&gclid=EAIaIQobChMIzrzJj8P-4wIVCMJkCh1i1ArmEAYYASABEgIObfD_BwE
# ~9.2 hours on two Intel Xeon 12-core Haswell processors (24 cores in total) 

chain1 <- SimAnneal(existing.sites = coord.sampled, 
                    alt.sites = coord.unsampled, 
                    n.choose = 3, 
                    rho = "logYValue0.3", 
                    disease.d.set = krige0.3.sim@data, 
                    obj.fun = OBJ1, 
                    initial.ml = initial.ml.3, 
                    neigh.fun = neigh.fun, 
                    T0 = 0.075, 
                    alpha = 0.9987, 
                    T.thres = 1e-6)
# Out:
# [1] "T = 0.074902; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.350239"
# [1] "T = 0.074805; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.350239"
# [1] "T = 0.074708; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.350239"
# [1] "T = 0.074611; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.350239"
# [1] "T = 0.074514; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.392228"
# [1] "T = 0.074417; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.392228"
# [1] "T = 0.07432; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.392228"
# [1] "T = 0.074224; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.392228"
# [1] "T = 0.074127; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.392228"
# [1] "T = 0.074031; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.474197"
# [1] "T = 0.073934; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.608148"
# [1] "T = 0.073838; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.522943"
# [1] "T = 0.073742; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.522943"
# [1] "T = 0.073646; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.522943"
# [1] "T = 0.073551; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.522943"
# [1] "T = 0.073455; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.446849"
# [1] "T = 0.07336; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.446849"
# [1] "T = 0.073264; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.424773"
# [1] "T = 0.073169; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.424773"
# [1] "T = 0.073074; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.424773"
# [1] "T = 0.072979; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.431822"
# [1] "T = 0.072884; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.387712"
# [1] "T = 0.072789; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.387712"
# [1] "T = 0.072695; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.387712"
# [1] "T = 0.0726; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.387712"
# [1] "T = 0.072506; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.387712"
# [1] "T = 0.072412; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.44494"
# [1] "T = 0.072317; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.473299"
# [1] "T = 0.072223; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.546031"
# [1] "T = 0.072129; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.5425"
# [1] "T = 0.072036; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.45207"
# [1] "T = 0.071942; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.45207"
# [1] "T = 0.071849; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.412358"
# [1] "T = 0.071755; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.374253"
# [1] "T = 0.071662; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.374253"
# [1] "T = 0.071569; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.425113"
# [1] "T = 0.071476; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.395976"
# [1] "T = 0.071383; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.395976"
# [1] "T = 0.07129; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.395976"
# [1] "T = 0.071197; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.395976"
# [1] "T = 0.071105; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.403263"
# [1] "T = 0.071012; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.35451"
# [1] "T = 0.07092; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.35451"
# [1] "T = 0.070828; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.35451"
# [1] "T = 0.070736; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.35451"
# [1] "T = 0.070644; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.35451"
# [1] "T = 0.070552; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.35451"
# [1] "T = 0.07046; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.440613"
# [1] "T = 0.070369; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.417239"
# [1] "T = 0.070277; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.417239"
# [1] "T = 0.070186; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.417239"
# [1] "T = 0.070094; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.417239"
# [1] "T = 0.070003; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.417239"
# [1] "T = 0.069912; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.393361"
# [1] "T = 0.069821; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.393361"
# [1] "T = 0.069731; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.393361"
# [1] "T = 0.06964; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.43139"
# [1] "T = 0.06955; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.393361"
# [1] "T = 0.069459; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.393361"
# [1] "T = 0.069369; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.393361"
# [1] "T = 0.069279; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.425532"
# [1] "T = 0.069189; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.425532"
# [1] "T = 0.069099; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.415715"
# [1] "T = 0.069009; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.415715"
# [1] "T = 0.068919; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.415715"
# [1] "T = 0.068829; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.537136"
# [1] "T = 0.06874; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.537136"
# [1] "T = 0.068651; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.482506"
# [1] "T = 0.068561; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.469344"
# [1] "T = 0.068472; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.469344"
# [1] "T = 0.068383; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.413416"
# [1] "T = 0.068294; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.467207"
# [1] "T = 0.068206; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.526934"
# [1] "T = 0.068117; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.526934"
# [1] "T = 0.068028; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.44139"
# [1] "T = 0.06794; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.384839"
# [1] "T = 0.067852; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.384839"
# [1] "T = 0.067763; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.384839"
# [1] "T = 0.067675; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.384839"
# [1] "T = 0.067587; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.384839"
# [1] "T = 0.067499; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.36601"
# [1] "T = 0.067412; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.36601"
# [1] "T = 0.067324; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.36601"
# [1] "T = 0.067237; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.36601"
# [1] "T = 0.067149; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.36601"
# [1] "T = 0.067062; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.358893"
# [1] "T = 0.066975; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.358893"
# [1] "T = 0.066888; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.358893"
# [1] "T = 0.066801; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.358893"
# [1] "T = 0.066714; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.358893"
# [1] "T = 0.066627; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.358893"
# [1] "T = 0.06654; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.358893"
# [1] "T = 0.066454; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.359612"
# [1] "T = 0.066368; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.399743"
# [1] "T = 0.066281; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.410133"
# [1] "T = 0.066195; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.374773"
# [1] "T = 0.066109; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.374773"
# [1] "T = 0.066023; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.367949"
# [1] "T = 0.065937; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.367949"
# [1] "T = 0.065852; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.482594"
# [1] "T = 0.065766; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.474794"
# [1] "T = 0.06568; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.4925"
# [1] "T = 0.065595; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.519468"
# [1] "T = 0.06551; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.519468"
# [1] "T = 0.065425; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.477416"
# [1] "T = 0.06534; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.477416"
# [1] "T = 0.065255; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.44139"
# [1] "T = 0.06517; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.44139"
# [1] "T = 0.065085; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.432537"
# [1] "T = 0.065001; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.485744"
# [1] "T = 0.064916; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.500312"
# [1] "T = 0.064832; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.490319"
# [1] "T = 0.064747; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.479919"
# [1] "T = 0.064663; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.449459"
# [1] "T = 0.064579; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.373545"
# [1] "T = 0.064495; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.373545"
# [1] "T = 0.064411; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.46023"
# [1] "T = 0.064328; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.471001"
# [1] "T = 0.064244; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.443968"
# [1] "T = 0.06416; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.443968"
# [1] "T = 0.064077; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.443968"
# [1] "T = 0.063994; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.376498"
# [1] "T = 0.063911; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.376498"
# [1] "T = 0.063827; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.433928"
# [1] "T = 0.063744; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.424466"
# [1] "T = 0.063662; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.446506"
# [1] "T = 0.063579; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.446506"
# [1] "T = 0.063496; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.446506"
# [1] "T = 0.063414; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.492371"
# [1] "T = 0.063331; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.443968"
# [1] "T = 0.063249; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.424013"
# [1] "T = 0.063167; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.480462"
# [1] "T = 0.063085; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.485004"
# [1] "T = 0.063003; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.485004"
# [1] "T = 0.062921; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.485004"
# [1] "T = 0.062839; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.485004"
# [1] "T = 0.062757; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.485004"
# [1] "T = 0.062676; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.444253"
# [1] "T = 0.062594; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.444253"
# [1] "T = 0.062513; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.444253"
# [1] "T = 0.062431; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.444253"
# [1] "T = 0.06235; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.444253"
# [1] "T = 0.062269; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.441196"
# [1] "T = 0.062188; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.452088"
# [1] "T = 0.062107; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.435673"
# [1] "T = 0.062027; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.424773"
# [1] "T = 0.061946; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.439491"
# [1] "T = 0.061866; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.439491"
# [1] "T = 0.061785; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.369884"
# [1] "T = 0.061705; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.416621"
# [1] "T = 0.061625; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.416621"
# [1] "T = 0.061544; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.408117"
# [1] "T = 0.061464; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.408117"
# [1] "T = 0.061385; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.387712"
# [1] "T = 0.061305; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.387712"
# [1] "T = 0.061225; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.387712"
# [1] "T = 0.061145; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.46023"
# [1] "T = 0.061066; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.479095"
# [1] "T = 0.060987; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.479095"
# [1] "T = 0.060907; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.414849"
# [1] "T = 0.060828; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.414849"
# [1] "T = 0.060749; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.483607"
# [1] "T = 0.06067; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.467282"
# [1] "T = 0.060591; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.467282"
# [1] "T = 0.060512; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.467282"
# [1] "T = 0.060434; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.467282"
# [1] "T = 0.060355; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.417653"
# [1] "T = 0.060277; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.417653"
# [1] "T = 0.060198; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.376112"
# [1] "T = 0.06012; BestID:5 19 3; BestCost:0.350239; CurrentCost:0.376112"
# [1] "T = 0.060042; BestID:17 5 15; BestCost:0.349068; CurrentCost:0.349068"
# [1] "T = 0.059964; BestID:17 5 15; BestCost:0.349068; CurrentCost:0.349068"
# [1] "T = 0.059886; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.347889"
# [1] "T = 0.059808; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.347889"
# [1] "T = 0.05973; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.434616"
# [1] "T = 0.059653; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.434616"
# [1] "T = 0.059575; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.395604"
# [1] "T = 0.059498; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.4442"
# [1] "T = 0.05942; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.418037"
# [1] "T = 0.059343; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.39286"
# [1] "T = 0.059266; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.418037"
# [1] "T = 0.059189; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.39286"
# [1] "T = 0.059112; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.425516"
# [1] "T = 0.059035; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.392093"
# [1] "T = 0.058958; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.369338"
# [1] "T = 0.058882; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.369338"
# [1] "T = 0.058805; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.414433"
# [1] "T = 0.058729; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.391827"
# [1] "T = 0.058652; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.391827"
# [1] "T = 0.058576; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.391827"
# [1] "T = 0.0585; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.350905"
# [1] "T = 0.058424; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.350905"
# [1] "T = 0.058348; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.350905"
# [1] "T = 0.058272; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.350905"
# [1] "T = 0.058196; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.350905"
# [1] "T = 0.058121; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.350905"
# [1] "T = 0.058045; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.350905"
# [1] "T = 0.05797; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.350905"
# [1] "T = 0.057894; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.383337"
# [1] "T = 0.057819; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.371707"
# [1] "T = 0.057744; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.415748"
# [1] "T = 0.057669; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.418194"
# [1] "T = 0.057594; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.418194"
# [1] "T = 0.057519; BestID:5 15 19; BestCost:0.347889; CurrentCost:0.362749"
# [1] "T = 0.057444; BestID:19 22 3; BestCost:0.331975; CurrentCost:0.331975"
# [1] "T = 0.05737; BestID:19 22 3; BestCost:0.331975; CurrentCost:0.414772"
# [1] "T = 0.057295; BestID:19 22 3; BestCost:0.331975; CurrentCost:0.475037"
# [1] "T = 0.05722; BestID:19 22 3; BestCost:0.331975; CurrentCost:0.596847"
# [1] "T = 0.057146; BestID:19 22 3; BestCost:0.331975; CurrentCost:0.514512"
# [1] "T = 0.057072; BestID:19 22 3; BestCost:0.331975; CurrentCost:0.511457"
# [1] "T = 0.056998; BestID:19 22 3; BestCost:0.331975; CurrentCost:0.392093"
# [1] "T = 0.056924; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 0.05685; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 0.056776; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.410531"
# [1] "T = 0.056702; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.410531"
# [1] "T = 0.056628; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.410531"
# [1] "T = 0.056554; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.406191"
# [1] "T = 0.056481; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.486445"
# [1] "T = 0.056408; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.486445"
# [1] "T = 0.056334; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.486445"
# [1] "T = 0.056261; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.486445"
# [1] "T = 0.056188; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.478245"
# [1] "T = 0.056115; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.481221"
# [1] "T = 0.056042; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.507132"
# [1] "T = 0.055969; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.507132"
# [1] "T = 0.055896; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.448012"
# [1] "T = 0.055824; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.362749"
# [1] "T = 0.055751; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.362749"
# [1] "T = 0.055679; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.3295"
# [1] "T = 0.055606; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.3295"
# [1] "T = 0.055534; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.3295"
# [1] "T = 0.055462; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.353718"
# [1] "T = 0.05539; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.400246"
# [1] "T = 0.055318; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.400246"
# [1] "T = 0.055246; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.433621"
# [1] "T = 0.055174; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.371444"
# [1] "T = 0.055102; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.371444"
# [1] "T = 0.05503; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.415796"
# [1] "T = 0.054959; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.415796"
# [1] "T = 0.054887; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.436517"
# [1] "T = 0.054816; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.37647"
# [1] "T = 0.054745; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.411632"
# [1] "T = 0.054674; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.371707"
# [1] "T = 0.054603; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.371707"
# [1] "T = 0.054532; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.371707"
# [1] "T = 0.054461; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.371707"
# [1] "T = 0.05439; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.430115"
# [1] "T = 0.054319; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.395196"
# [1] "T = 0.054249; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.395196"
# [1] "T = 0.054178; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.399003"
# [1] "T = 0.054108; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.399003"
# [1] "T = 0.054037; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.399003"
# [1] "T = 0.053967; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.502729"
# [1] "T = 0.053897; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.502729"
# [1] "T = 0.053827; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.502729"
# [1] "T = 0.053757; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.526529"
# [1] "T = 0.053687; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.526529"
# [1] "T = 0.053617; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.489332"
# [1] "T = 0.053547; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.514529"
# [1] "T = 0.053478; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.501794"
# [1] "T = 0.053408; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.449764"
# [1] "T = 0.053339; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.427617"
# [1] "T = 0.05327; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.427617"
# [1] "T = 0.0532; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.397174"
# [1] "T = 0.053131; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.397174"
# [1] "T = 0.053062; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.397174"
# [1] "T = 0.052993; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.532956"
# [1] "T = 0.052924; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.532956"
# [1] "T = 0.052855; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.546527"
# [1] "T = 0.052787; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.411912"
# [1] "T = 0.052718; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.35948"
# [1] "T = 0.05265; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.35948"
# [1] "T = 0.052581; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.370988"
# [1] "T = 0.052513; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.375865"
# [1] "T = 0.052445; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.375865"
# [1] "T = 0.052376; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.375865"
# [1] "T = 0.052308; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.391827"
# [1] "T = 0.05224; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.450146"
# [1] "T = 0.052172; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.436732"
# [1] "T = 0.052104; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.445658"
# [1] "T = 0.052037; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.445658"
# [1] "T = 0.051969; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.385463"
# [1] "T = 0.051902; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.461285"
# [1] "T = 0.051834; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.462245"
# [1] "T = 0.051767; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.408117"
# [1] "T = 0.051699; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.408117"
# [1] "T = 0.051632; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.408117"
# [1] "T = 0.051565; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.442329"
# [1] "T = 0.051498; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.385181"
# [1] "T = 0.051431; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.393398"
# [1] "T = 0.051364; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.393398"
# [1] "T = 0.051297; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.374504"
# [1] "T = 0.051231; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.374504"
# [1] "T = 0.051164; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.393398"
# [1] "T = 0.051098; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.41794"
# [1] "T = 0.051031; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.371822"
# [1] "T = 0.050965; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.36686"
# [1] "T = 0.050899; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.36686"
# [1] "T = 0.050832; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.36686"
# [1] "T = 0.050766; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.36686"
# [1] "T = 0.0507; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.371822"
# [1] "T = 0.050634; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.433014"
# [1] "T = 0.050569; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.44224"
# [1] "T = 0.050503; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.522681"
# [1] "T = 0.050437; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.489332"
# [1] "T = 0.050372; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.386979"
# [1] "T = 0.050306; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.429622"
# [1] "T = 0.050241; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.429622"
# [1] "T = 0.050175; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.444376"
# [1] "T = 0.05011; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.481807"
# [1] "T = 0.050045; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.481807"
# [1] "T = 0.04998; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.481807"
# [1] "T = 0.049915; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.481807"
# [1] "T = 0.04985; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.481807"
# [1] "T = 0.049785; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.414081"
# [1] "T = 0.049721; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.384839"
# [1] "T = 0.049656; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.384839"
# [1] "T = 0.049591; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.384839"
# [1] "T = 0.049527; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.384839"
# [1] "T = 0.049463; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.384839"
# [1] "T = 0.049398; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.492257"
# [1] "T = 0.049334; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.479811"
# [1] "T = 0.04927; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.479811"
# [1] "T = 0.049206; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.517969"
# [1] "T = 0.049142; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.518907"
# [1] "T = 0.049078; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.518907"
# [1] "T = 0.049014; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.499192"
# [1] "T = 0.048951; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.499192"
# [1] "T = 0.048887; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.435611"
# [1] "T = 0.048823; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.435611"
# [1] "T = 0.04876; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.435611"
# [1] "T = 0.048697; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.435611"
# [1] "T = 0.048633; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.435611"
# [1] "T = 0.04857; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.435611"
# [1] "T = 0.048507; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.435611"
# [1] "T = 0.048444; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.435611"
# [1] "T = 0.048381; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.435611"
# [1] "T = 0.048318; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.435611"
# [1] "T = 0.048255; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.585968"
# [1] "T = 0.048192; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.579595"
# [1] "T = 0.04813; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.577417"
# [1] "T = 0.048067; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.570852"
# [1] "T = 0.048005; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.570852"
# [1] "T = 0.047942; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.607303"
# [1] "T = 0.04788; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.582241"
# [1] "T = 0.047818; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.588302"
# [1] "T = 0.047756; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.480156"
# [1] "T = 0.047693; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.467659"
# [1] "T = 0.047631; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.480986"
# [1] "T = 0.04757; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.463919"
# [1] "T = 0.047508; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.463508"
# [1] "T = 0.047446; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.463508"
# [1] "T = 0.047384; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.451841"
# [1] "T = 0.047323; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.406191"
# [1] "T = 0.047261; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.417239"
# [1] "T = 0.0472; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.417239"
# [1] "T = 0.047138; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.393905"
# [1] "T = 0.047077; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.393905"
# [1] "T = 0.047016; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.39286"
# [1] "T = 0.046955; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.349068"
# [1] "T = 0.046894; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.354794"
# [1] "T = 0.046833; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.354794"
# [1] "T = 0.046772; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.354794"
# [1] "T = 0.046711; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.354794"
# [1] "T = 0.04665; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.354794"
# [1] "T = 0.04659; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.354794"
# [1] "T = 0.046529; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.354794"
# [1] "T = 0.046469; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.354794"
# [1] "T = 0.046408; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.354794"
# [1] "T = 0.046348; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.354794"
# [1] "T = 0.046288; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.354794"
# [1] "T = 0.046227; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.354794"
# [1] "T = 0.046167; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.354794"
# [1] "T = 0.046107; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.354794"
# [1] "T = 0.046047; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.354794"
# [1] "T = 0.045988; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.354794"
# [1] "T = 0.045928; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.354794"
# [1] "T = 0.045868; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.349068"
# [1] "T = 0.045808; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.349068"
# [1] "T = 0.045749; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.349068"
# [1] "T = 0.045689; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.349068"
# [1] "T = 0.04563; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.397103"
# [1] "T = 0.045571; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.38874"
# [1] "T = 0.045511; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.38874"
# [1] "T = 0.045452; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.345537"
# [1] "T = 0.045393; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.345537"
# [1] "T = 0.045334; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.349068"
# [1] "T = 0.045275; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.349068"
# [1] "T = 0.045216; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.349068"
# [1] "T = 0.045158; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.349068"
# [1] "T = 0.045099; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.36686"
# [1] "T = 0.04504; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.36686"
# [1] "T = 0.044982; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.36686"
# [1] "T = 0.044923; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.36686"
# [1] "T = 0.044865; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.414761"
# [1] "T = 0.044806; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.417239"
# [1] "T = 0.044748; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.417239"
# [1] "T = 0.04469; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.328686"
# [1] "T = 0.044632; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.364396"
# [1] "T = 0.044574; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.364396"
# [1] "T = 0.044516; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.364396"
# [1] "T = 0.044458; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.364396"
# [1] "T = 0.0444; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.364396"
# [1] "T = 0.044343; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.364396"
# [1] "T = 0.044285; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.413379"
# [1] "T = 0.044227; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.413379"
# [1] "T = 0.04417; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.470197"
# [1] "T = 0.044112; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.454956"
# [1] "T = 0.044055; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.412715"
# [1] "T = 0.043998; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.412715"
# [1] "T = 0.043941; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.412715"
# [1] "T = 0.043884; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.396737"
# [1] "T = 0.043827; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.396737"
# [1] "T = 0.04377; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.413483"
# [1] "T = 0.043713; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.385463"
# [1] "T = 0.043656; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.350239"
# [1] "T = 0.043599; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.379918"
# [1] "T = 0.043542; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.379918"
# [1] "T = 0.043486; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.379918"
# [1] "T = 0.043429; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.370054"
# [1] "T = 0.043373; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.370054"
# [1] "T = 0.043316; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.436799"
# [1] "T = 0.04326; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.436799"
# [1] "T = 0.043204; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.375573"
# [1] "T = 0.043148; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.375573"
# [1] "T = 0.043092; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.375573"
# [1] "T = 0.043036; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.437385"
# [1] "T = 0.04298; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.437385"
# [1] "T = 0.042924; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.437385"
# [1] "T = 0.042868; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.452589"
# [1] "T = 0.042812; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.452589"
# [1] "T = 0.042757; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.475037"
# [1] "T = 0.042701; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.475037"
# [1] "T = 0.042645; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.475037"
# [1] "T = 0.04259; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.476263"
# [1] "T = 0.042535; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.397044"
# [1] "T = 0.042479; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.418784"
# [1] "T = 0.042424; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.383337"
# [1] "T = 0.042369; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.383337"
# [1] "T = 0.042314; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.408082"
# [1] "T = 0.042259; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.369649"
# [1] "T = 0.042204; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.369649"
# [1] "T = 0.042149; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.364892"
# [1] "T = 0.042094; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.364892"
# [1] "T = 0.04204; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.42166"
# [1] "T = 0.041985; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.355468"
# [1] "T = 0.04193; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.359612"
# [1] "T = 0.041876; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.359612"
# [1] "T = 0.041821; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.359612"
# [1] "T = 0.041767; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.359612"
# [1] "T = 0.041713; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.359612"
# [1] "T = 0.041659; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.36666"
# [1] "T = 0.041604; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.36666"
# [1] "T = 0.04155; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.438575"
# [1] "T = 0.041496; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.438575"
# [1] "T = 0.041442; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.442293"
# [1] "T = 0.041388; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.36601"
# [1] "T = 0.041335; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.36601"
# [1] "T = 0.041281; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.440303"
# [1] "T = 0.041227; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.440303"
# [1] "T = 0.041174; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.545786"
# [1] "T = 0.04112; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.523308"
# [1] "T = 0.041067; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.523308"
# [1] "T = 0.041013; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.428199"
# [1] "T = 0.04096; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.442073"
# [1] "T = 0.040907; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.407005"
# [1] "T = 0.040854; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.404203"
# [1] "T = 0.0408; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.404203"
# [1] "T = 0.040747; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.350239"
# [1] "T = 0.040694; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.350239"
# [1] "T = 0.040642; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.350239"
# [1] "T = 0.040589; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.350239"
# [1] "T = 0.040536; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.350239"
# [1] "T = 0.040483; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.350239"
# [1] "T = 0.040431; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.350239"
# [1] "T = 0.040378; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.414841"
# [1] "T = 0.040326; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.370054"
# [1] "T = 0.040273; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.416909"
# [1] "T = 0.040221; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.416909"
# [1] "T = 0.040168; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.416909"
# [1] "T = 0.040116; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.416909"
# [1] "T = 0.040064; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.370054"
# [1] "T = 0.040012; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.370054"
# [1] "T = 0.03996; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.331975"
# [1] "T = 0.039908; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.331975"
# [1] "T = 0.039856; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.331975"
# [1] "T = 0.039804; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.331975"
# [1] "T = 0.039753; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.331975"
# [1] "T = 0.039701; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.331975"
# [1] "T = 0.039649; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.331975"
# [1] "T = 0.039598; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.401771"
# [1] "T = 0.039546; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.419656"
# [1] "T = 0.039495; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.419656"
# [1] "T = 0.039444; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.419656"
# [1] "T = 0.039392; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.419656"
# [1] "T = 0.039341; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.436241"
# [1] "T = 0.03929; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.489149"
# [1] "T = 0.039239; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.489149"
# [1] "T = 0.039188; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.479288"
# [1] "T = 0.039137; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.479288"
# [1] "T = 0.039086; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.434134"
# [1] "T = 0.039035; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.434134"
# [1] "T = 0.038984; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.463043"
# [1] "T = 0.038934; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.4442"
# [1] "T = 0.038883; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.422161"
# [1] "T = 0.038833; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.422161"
# [1] "T = 0.038782; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.35451"
# [1] "T = 0.038732; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.352878"
# [1] "T = 0.038681; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.352878"
# [1] "T = 0.038631; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.352878"
# [1] "T = 0.038581; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.352878"
# [1] "T = 0.038531; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.352878"
# [1] "T = 0.038481; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.352878"
# [1] "T = 0.038431; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.420734"
# [1] "T = 0.038381; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.406103"
# [1] "T = 0.038331; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.399042"
# [1] "T = 0.038281; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.334198"
# [1] "T = 0.038231; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.334198"
# [1] "T = 0.038181; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.354794"
# [1] "T = 0.038132; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.369884"
# [1] "T = 0.038082; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.471526"
# [1] "T = 0.038033; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.471526"
# [1] "T = 0.037983; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.471526"
# [1] "T = 0.037934; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.474525"
# [1] "T = 0.037885; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.474525"
# [1] "T = 0.037835; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.443169"
# [1] "T = 0.037786; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.452088"
# [1] "T = 0.037737; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.452088"
# [1] "T = 0.037688; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.432583"
# [1] "T = 0.037639; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.432583"
# [1] "T = 0.03759; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.432583"
# [1] "T = 0.037541; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.432583"
# [1] "T = 0.037492; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.432583"
# [1] "T = 0.037444; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.42166"
# [1] "T = 0.037395; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.42166"
# [1] "T = 0.037346; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.42166"
# [1] "T = 0.037298; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.42166"
# [1] "T = 0.037249; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.493921"
# [1] "T = 0.037201; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.451766"
# [1] "T = 0.037153; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.451766"
# [1] "T = 0.037104; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.451766"
# [1] "T = 0.037056; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.481959"
# [1] "T = 0.037008; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.481959"
# [1] "T = 0.03696; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.481959"
# [1] "T = 0.036912; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.481959"
# [1] "T = 0.036864; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.481959"
# [1] "T = 0.036816; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.451961"
# [1] "T = 0.036768; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.435037"
# [1] "T = 0.03672; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.386355"
# [1] "T = 0.036672; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.357559"
# [1] "T = 0.036625; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.357559"
# [1] "T = 0.036577; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.357559"
# [1] "T = 0.03653; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.357559"
# [1] "T = 0.036482; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.357559"
# [1] "T = 0.036435; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.442293"
# [1] "T = 0.036387; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.543605"
# [1] "T = 0.03634; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.543605"
# [1] "T = 0.036293; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.543605"
# [1] "T = 0.036246; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.435673"
# [1] "T = 0.036198; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.435673"
# [1] "T = 0.036151; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.435673"
# [1] "T = 0.036104; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.435673"
# [1] "T = 0.036057; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.351068"
# [1] "T = 0.036011; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.351068"
# [1] "T = 0.035964; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.368599"
# [1] "T = 0.035917; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.399743"
# [1] "T = 0.03587; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.399743"
# [1] "T = 0.035824; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.399743"
# [1] "T = 0.035777; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.399743"
# [1] "T = 0.035731; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.424493"
# [1] "T = 0.035684; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.418848"
# [1] "T = 0.035638; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.418848"
# [1] "T = 0.035591; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.418848"
# [1] "T = 0.035545; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.389775"
# [1] "T = 0.035499; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.396962"
# [1] "T = 0.035453; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.396962"
# [1] "T = 0.035407; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.396962"
# [1] "T = 0.035361; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.386355"
# [1] "T = 0.035315; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.386355"
# [1] "T = 0.035269; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.386355"
# [1] "T = 0.035223; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.386355"
# [1] "T = 0.035177; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.386355"
# [1] "T = 0.035131; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.386355"
# [1] "T = 0.035086; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.379959"
# [1] "T = 0.03504; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.379959"
# [1] "T = 0.034995; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.39051"
# [1] "T = 0.034949; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.424466"
# [1] "T = 0.034904; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.424466"
# [1] "T = 0.034858; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.424466"
# [1] "T = 0.034813; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.446506"
# [1] "T = 0.034768; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.446506"
# [1] "T = 0.034722; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.379959"
# [1] "T = 0.034677; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.379959"
# [1] "T = 0.034632; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.379959"
# [1] "T = 0.034587; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.379959"
# [1] "T = 0.034542; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.379959"
# [1] "T = 0.034497; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.379959"
# [1] "T = 0.034453; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.379959"
# [1] "T = 0.034408; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.374253"
# [1] "T = 0.034363; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.374253"
# [1] "T = 0.034318; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.374253"
# [1] "T = 0.034274; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.374253"
# [1] "T = 0.034229; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.374253"
# [1] "T = 0.034185; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.374253"
# [1] "T = 0.03414; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.374253"
# [1] "T = 0.034096; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.374253"
# [1] "T = 0.034052; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.374253"
# [1] "T = 0.034007; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.374253"
# [1] "T = 0.033963; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.374253"
# [1] "T = 0.033919; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.374253"
# [1] "T = 0.033875; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.374253"
# [1] "T = 0.033831; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.374253"
# [1] "T = 0.033787; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.374253"
# [1] "T = 0.033743; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.357678"
# [1] "T = 0.033699; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.357678"
# [1] "T = 0.033655; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.357678"
# [1] "T = 0.033611; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.357678"
# [1] "T = 0.033568; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.357678"
# [1] "T = 0.033524; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.357678"
# [1] "T = 0.033481; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.357678"
# [1] "T = 0.033437; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.357678"
# [1] "T = 0.033394; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.357678"
# [1] "T = 0.03335; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.357678"
# [1] "T = 0.033307; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.357678"
# [1] "T = 0.033263; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.357678"
# [1] "T = 0.03322; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.371222"
# [1] "T = 0.033177; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.371222"
# [1] "T = 0.033134; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.371222"
# [1] "T = 0.033091; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.371222"
# [1] "T = 0.033048; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.371222"
# [1] "T = 0.033005; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.371222"
# [1] "T = 0.032962; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.383494"
# [1] "T = 0.032919; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.383494"
# [1] "T = 0.032876; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.383494"
# [1] "T = 0.032834; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.404203"
# ...
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"
# [1] "T = 1e-06; BestID:7 17 15; BestCost:0.325823; CurrentCost:0.325823"

# %%
chain2 <- SimAnneal(existing.sites = coord.sampled, alt.sites = coord.unsampled, n.choose = 3, rho = "logYValue0.3", disease.d.set = krige0.3.sim@data, obj.fun = OBJ1, initial.ml = initial.ml.3, neigh.fun = neigh.fun, T0 = 0.075, alpha = 0.9987, T.thres = 1e-6)

# %%
chain3 <- SimAnneal(existing.sites = coord.sampled, alt.sites = coord.unsampled, n.choose = 3, rho = "logYValue0.3", disease.d.set = krige0.3.sim@data, obj.fun = OBJ1, initial.ml = initial.ml.3, neigh.fun = neigh.fun, T0 = 0.075, alpha = 0.9987, T.thres = 1e-6)

# %%
SA1 <- rbind(chain1, chain1, chain1)     ## skipping test with 3 trials

##SA1 <- rbind(chain1, chain2, chain3)
SA1 <- data.frame(SA1)

# %%
#==== plot results for selecting three additional sites for spatial prediction ====
#======= Figure 5 =======
# rho = 0.3, OFV 1
# SA1 <-  read.csv("SA.OFV1.03.csv")
SA1$BestID <- as.character(SA1$BestID)
SA1$criterion.result <- as.character(SA1$criterion.result)

# %%
# plot the chain
result.SA <- NULL
for(i in 1:nrow(SA1))
{
  result.SA <- rbind(result.SA, data.frame(iter = rep(i, each = length(as.numeric(unlist(strsplit(SA1[1,3],","))))), step = 1:length(as.numeric(unlist(strsplit(SA1[1,3],",")))), OFV = as.numeric(unlist(strsplit(SA1[i,3],",")))))
}

# %%
Figure5A <- ggplot(result.SA, aes(x = step, y = OFV, col = as.factor(iter), group = iter)) + 
  geom_line() + 
  theme_bw() + 
  xlab("Number of iterations") + 
  ylab("OFV1") + 
  guides(col = FALSE) + 
  ggtitle("(A) Examples of SA runs")

# %%
BestID <- as.numeric(unlist(strsplit(SA1$BestID[1], ",")))

# %%
Figure5B <- ggplot() + 
  geom_tile(data = X.coord, aes(x = x, y = y, fill = Y0.3)) + 
  geom_contour(data = X.coord, aes(x, y, z = Xvalue), col = "gray")+ 
  geom_point(data = coord.unsampled, aes(x, y), col = "gray60") + 
  geom_point(data = coord.sampled, aes(x, y), shape = 17, size = 2) + 
  geom_point(data = coord.unsampled[BestID,], aes(x = x, y = y), size = 4, shape = 17, col = "blue") + 
  scale_fill_distiller(palette = "RdYlGn", limits = c(min(c(coord.sampled$YValue0.1, coord.sampled$YValue0.3, X.coord$Y0.1, X.coord$Y0.3))-0.1, max(c(coord.sampled$YValue0.1, coord.sampled$YValue0.3, X.coord$Y0.1, X.coord$Y0.3))+0.1))  + 
  scale_color_manual(values = c("grey","black")) + labs(color = "", fill = "var.both") + 
  scale_x_continuous(limits = c(0,1), expand = c(0,0)) + 
  scale_y_continuous(limits = c(0,1), expand = c(0,0)) + 
  ggtitle("(B) Locations of 3 optimal sites") +
  guides(color = FALSE, fill = FALSE) + 
  xlab("") + 
  ylab("") +
  coord_equal() + 
  theme_bw()

# %%
plot_grid(Figure5A, Figure5B)
# Out:
# plot without title
